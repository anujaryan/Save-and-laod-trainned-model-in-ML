# %%
import pandas as pd

# %%
from sklearn import linear_model

# %%
df = pd.read_csv("homeprices.csv")
df
# Out:
#    area  bedrooms  age   price
# 0  2600         3   20  550000
# 1  3000         4   15  565000
# 2  3200         4   18  610000
# 3  3600         3   30  595000
# 4  4000         5    8  760000
# 5  4100         6    8  810000

# %%
model = linear_model.LinearRegression()
model.fit(df[['area','bedrooms','age']],df.price)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
model.intercept_
# Out:
# np.float64(221323.0018654043)

# %%
model.predict([[5000,3,12]])
# Out:
# C:\Users\anujs\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([813021.2369063])

# %% [markdown]
# # Save model to file using pickle

# %%
import pickle

# %%
with open('model_pickle','wb') as f:
    mp = pickle.dump(model,f)

# %%
with open('model_pickle','rb') as f:
    mp = pickle.load(f)

# %% [markdown]
# # load saved model

# %%
mp.predict([[5000,3,12]])
# Out:
# C:\Users\anujs\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([813021.2369063])

# %% [markdown]
# # Save Trained Model using joblib

# %%
import joblib

# %%
joblib.dump(model,'model_joblib')
# Out:
# ['model_joblib']

# %% [markdown]
# # Load model using joblib

# %%
mj = joblib.load('model_joblib')

# %%
mj.coef_
# Out:
# array([  112.06244194, 23388.88007794, -3231.71790863])

# %%
mj.intercept_
# Out:
# np.float64(221323.0018654043)

# %%
mj.predict([[5000,3,12]])
# Out:
# C:\Users\anujs\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([813021.2369063])
